# %% [markdown]
# # Exploring Titanic Dataset

# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_train = pd.read_csv('titanic_data/train.csv')
df_test = pd.read_csv('titanic_data/test.csv')

# %%
df_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df_train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# Survived: Survived (1) or died (0)
#
# Pclass: Passenger’s class
#
# Name: Passenger’s name
#
# Sex: Passenger’s sex
#
# Age: Passenger’s age
#
# SibSp: Number of siblings/spouses aboard
#
# Parch: Number of parents/children aboard
#
# Ticket: Ticket number
#
# Fare: Fare
#
# Cabin: Cabin
#
# Embarked: Port of embarkation

# %%
# Count survived
total_no_of_passengers = len(df_train['Survived'])

for group, frame in df_train.groupby('Survived'):
    print("Survived " + str(group) + " : " + str(len(frame)) + " "+ str(round(len(frame)*100/total_no_of_passengers,1)) + '%' )
# Out:
# Survived 0 : 549 61.6%
# Survived 1 : 342 38.4%

# %%
for group, frame in df_train[['Sex']].groupby(['Sex'], as_index=False):
    print("{} : {}".format(group, len(frame)))
# Out:
# female : 314
# male : 577

# %%
df_train[['Sex','Survived']].groupby(['Sex'], as_index=False).count()
# Out:
#       Sex  Survived
# 0  female       314
# 1    male       577

# %%
df_train[['Sex','Survived']].groupby(['Sex'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#       Sex  Survived
# 0  female  0.742038
# 1    male  0.188908

# %%
df_train[['Pclass','Survived']].groupby(['Pclass'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#    Pclass  Survived
# 0       1  0.629630
# 1       2  0.472826
# 2       3  0.242363

# %%
df_train[['SibSp','Survived']].groupby(['SibSp'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#    SibSp  Survived
# 1      1  0.535885
# 2      2  0.464286
# 0      0  0.345395
# 3      3  0.250000
# 4      4  0.166667
# 5      5  0.000000
# 6      8  0.000000

# %%
df_train[['Parch','Survived']].groupby(['Parch'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#    Parch  Survived
# 3      3  0.600000
# 1      1  0.550847
# 2      2  0.500000
# 0      0  0.343658
# 5      5  0.200000
# 4      4  0.000000
# 6      6  0.000000

# %%
plt.figure()
_ = plt.hist(df_train['Age'], bins=25)
# Out:
# C:\Users\mirta\AppData\Roaming\Python\Python37\site-packages\numpy\lib\histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\Users\mirta\AppData\Roaming\Python\Python37\site-packages\numpy\lib\histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
df_train_survived = df_train[['Age','Survived']].where(df_train['Survived']==1).dropna()
df_train_not_survived = df_train[['Age','Survived']].where(df_train['Survived']==0).dropna()
plt.figure()
plt.figure(figsize = (15,6))
ax1 = plt.subplot(1,2,1)
_ = ax1.hist(df_train_survived['Age'], bins=20)

ax2 = plt.subplot(1,2,2)
_ = ax2.hist(df_train_not_survived['Age'], bins=20)

# %%
age_hist = sns.FacetGrid(df_train, col='Survived')
age_hist.map(plt.hist, 'Age', bins=5)
age_hist.set_ylabels('Number')

# %%
Pclass_hist = sns.FacetGrid(df_train, col='Pclass')
Pclass_hist.map(plt.hist, 'Age', bins=20)
Pclass_hist.set_ylabels('Number')

# %%
Pclass_hist = sns.FacetGrid(df_train, col='Pclass')
Pclass_hist.map(plt.hist, 'Fare', bins=20)
Pclass_hist.set_ylabels('Number')

# %%
Pclass_hist = sns.FacetGrid(df_train, col='Pclass', height=3.2, aspect=1)
Pclass_hist.map(plt.hist, 'Fare', bins=20)
Pclass_hist.set_ylabels('Number')

# %%
pclass_age_grid = sns.FacetGrid(df_train, col='Survived', row='Pclass', height=2.2, aspect=1.6)
pclass_age_grid.map(plt.hist, 'Age', alpha=0.5, bins=20)
pclass_age_grid.add_legend()

# %%
grid = sns.FacetGrid(df_train, row='Embarked', height=2.8, aspect=2)
grid.map(sns.pointplot, 'Pclass', 'Survived', 'Sex', palette='deep')
grid.add_legend()
# Out:
# C:\Users\mirta\Anaconda3\envs\Python 3.7\lib\site-packages\seaborn\axisgrid.py:728: UserWarning: Using the pointplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
# C:\Users\mirta\Anaconda3\envs\Python 3.7\lib\site-packages\seaborn\axisgrid.py:733: UserWarning: Using the pointplot function without specifying `hue_order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
grid = sns.FacetGrid(df_train, row='SibSp', height=2.8, aspect=2)
grid.map(sns.pointplot, 'Pclass', 'Survived', 'Sex', palette='deep')
grid.add_legend()
# Out:
# C:\Users\mirta\Anaconda3\envs\Python 3.7\lib\site-packages\seaborn\axisgrid.py:728: UserWarning: Using the pointplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
# C:\Users\mirta\Anaconda3\envs\Python 3.7\lib\site-packages\seaborn\axisgrid.py:733: UserWarning: Using the pointplot function without specifying `hue_order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %% [markdown]
# ### Fare Analysis of passengers who survived based on Embarking Zone

# %%
grid = sns.FacetGrid(df_train, row='Embarked')
grid.map(sns.barplot, 'Fare', 'Sex')
grid.add_legend()
# Out:
# C:\Users\mirta\Anaconda3\envs\Python 3.7\lib\site-packages\seaborn\axisgrid.py:728: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
grid = sns.FacetGrid(df_train, row='Embarked', col='Sex')
grid.map(sns.barplot, 'Fare')
grid.add_legend()
# Out:
# C:\Users\mirta\Anaconda3\envs\Python 3.7\lib\site-packages\seaborn\axisgrid.py:728: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
grid = sns.FacetGrid(df_train, row='Embarked', col='Pclass')
grid.map(sns.barplot, 'Fare','Sex')
grid.add_legend()
# Out:
# C:\Users\mirta\Anaconda3\envs\Python 3.7\lib\site-packages\seaborn\axisgrid.py:728: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
grid = sns.FacetGrid(df_train, row='Embarked', col='Survived', size=2.2, aspect=1.6)
grid.map(sns.barplot, 'Pclass', 'Fare', alpha=.5, ci=None)
grid.add_legend()
# Out:
# C:\Users\mirta\Anaconda3\envs\Python 3.7\lib\site-packages\seaborn\axisgrid.py:243: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\mirta\Anaconda3\envs\Python 3.7\lib\site-packages\seaborn\axisgrid.py:728: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
grid = sns.FacetGrid(df_train, row='Embarked', col='Survived', size=2.2, aspect=1.6)
grid.map(sns.barplot, 'Sex', 'Fare', alpha=.5, ci=None)
grid.add_legend()

# %%
grid = sns.FacetGrid(df_train, row='Pclass', col='Survived', size=2.2, aspect=1.6)
grid.map(sns.barplot, 'Sex', 'Fare', alpha=.5, ci=None)
grid.add_legend()

# %%
df_train = df_train.drop(['Ticket', 'Cabin'], axis=1)
df_test = df_test.drop(['Ticket', 'Cabin'], axis=1)
combine = [df_train, df_test]

for dataset in combine:
    dataset['Title'] = dataset.Name.str.extract('([A-Za-z]+)\.', expand=False)

pd.crosstab(df_train['Title'], df_train['Sex'])
# Out:
# Sex       female  male
# Title
# Capt           0     1
# Col            0     2
# Countess       1     0
# Don            0     1
# Dr             1     6
# Jonkheer       0     1
# Lady           1     0
# Major          0     2
# Master         0    40
# Miss         182     0
# Mlle           2     0
# Mme            1     0
# Mr             0   517
# Mrs          125     0
# Ms             1     0
# Rev            0     6
# Sir            0     1

# %%
for dataset in combine:
    dataset['Title'] = dataset['Title'].replace('Mlle', 'Miss')
    dataset['Title'] = dataset['Title'].replace('Ms', 'Miss')
    dataset['Title'] = dataset['Title'].replace('Mme', 'Mrs')
    dataset['Title'] = dataset['Title'].replace(['Lady', 'Countess','Don', 'Sir', 'Jonkheer', 'Dona'],'Royalty')
    dataset['Title'] = dataset['Title'].replace(['Capt', 'Col','Dr','Major','Rev'],'Special')

df_train[['Title','Survived']].groupby(['Title'], as_index=False).mean()
# Out:
#      Title  Survived
# 0   Master  0.575000
# 1     Miss  0.702703
# 2       Mr  0.156673
# 3      Mrs  0.793651
# 4  Royalty  0.600000
# 5  Special  0.277778

# %%
dataset[['Title']]

title_mapping =  {"Master": 1, "Miss": 2, "Mrs": 3, "Mr": 4, "Royalty": 5, "Special": 6}

for dataset in combine:
    dataset['Title'] = dataset['Title'].map(title_mapping)
    dataset['Title'] = dataset['Title'].fillna(0)

df_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch     Fare Embarked  Title
# 0        0   7.2500        S      4
# 1        0  71.2833        C      3
# 2        0   7.9250        S      2
# 3        0  53.1000        S      3
# 4        0   8.0500        S      4
# ..     ...      ...      ...    ...
# 886      0  13.0000        S      6
# 887      0  30.0000        S      2
# 888      2  23.4500        S      2
# 889      0  30.0000        C      4
# 890      0   7.7500        Q      4
#
# [891 rows x 11 columns]

# %%
df_train = df_train.drop(['Name', 'PassengerId'], axis=1)
df_test = df_test.drop(['Name'], axis=1)
combine = [df_train, df_test]

# %%
# Mapping sex to numbers
for dataset in combine:
    dataset['Sex'] = dataset['Sex'].map({'female':1, 'male':0}).astype(int)
    
df_train.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare Embarked  Title
# 0         0       3    0  22.0      1      0   7.2500        S      4
# 1         1       1    1  38.0      1      0  71.2833        C      3
# 2         1       3    1  26.0      0      0   7.9250        S      2
# 3         1       1    1  35.0      1      0  53.1000        S      3
# 4         0       3    0  35.0      0      0   8.0500        S      4

# %%
pclass_sex_age_grid = sns.FacetGrid(df_train, row='Pclass', col='Sex')
pclass_sex_age_grid.map(plt.hist, 'Age', alpha=0.5, bins=20)
pclass_sex_age_grid.add_legend()

# %%
df_train['Age'].isnull().sum() # No of null age
# Out:
# 177

# %%
df_train.isnull().sum() # null counts
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Fare          0
# Embarked      2
# Title         0
# dtype: int64

# %%
# Coming up with median age based on passenger class and sex

# %%
df_train.where(df_train['Sex']==0)
# Out:
#      Survived  Pclass  Sex   Age  SibSp  Parch   Fare Embarked  Title
# 0         0.0     3.0  0.0  22.0    1.0    0.0   7.25        S    4.0
# 1         NaN     NaN  NaN   NaN    NaN    NaN    NaN      NaN    NaN
# 2         NaN     NaN  NaN   NaN    NaN    NaN    NaN      NaN    NaN
# 3         NaN     NaN  NaN   NaN    NaN    NaN    NaN      NaN    NaN
# 4         0.0     3.0  0.0  35.0    0.0    0.0   8.05        S    4.0
# ..        ...     ...  ...   ...    ...    ...    ...      ...    ...
# 886       0.0     2.0  0.0  27.0    0.0    0.0  13.00        S    6.0
# 887       NaN     NaN  NaN   NaN    NaN    NaN    NaN      NaN    NaN
# 888       NaN     NaN  NaN   NaN    NaN    NaN    NaN      NaN    NaN
# 889       1.0     1.0  0.0  26.0    0.0    0.0  30.00        C    4.0
# 890       0.0     3.0  0.0  32.0    0.0    0.0   7.75        Q    4.0
#
# [891 rows x 9 columns]

# %%
df_train[(df_train['Sex']==0)]
# Out:
#      Survived  Pclass  Sex   Age  SibSp  Parch     Fare Embarked  Title
# 0           0       3    0  22.0      1      0   7.2500        S      4
# 4           0       3    0  35.0      0      0   8.0500        S      4
# 5           0       3    0   NaN      0      0   8.4583        Q      4
# 6           0       1    0  54.0      0      0  51.8625        S      4
# 7           0       3    0   2.0      3      1  21.0750        S      1
# ..        ...     ...  ...   ...    ...    ...      ...      ...    ...
# 883         0       2    0  28.0      0      0  10.5000        S      4
# 884         0       3    0  25.0      0      0   7.0500        S      4
# 886         0       2    0  27.0      0      0  13.0000        S      6
# 889         1       1    0  26.0      0      0  30.0000        C      4
# 890         0       3    0  32.0      0      0   7.7500        Q      4
#
# [577 rows x 9 columns]

# %%
df_train[(df_train['Sex']==0) & (df_train['Age']<20)]
# Out:
#      Survived  Pclass  Sex   Age  SibSp  Parch      Fare Embarked  Title
# 7           0       3    0   2.0      3      1   21.0750        S      1
# 16          0       3    0   2.0      4      1   29.1250        Q      1
# 27          0       1    0  19.0      3      2  263.0000        S      4
# 50          0       3    0   7.0      4      1   39.6875        S      1
# 59          0       3    0  11.0      5      2   46.9000        S      1
# ..        ...     ...  ...   ...    ...    ...       ...      ...    ...
# 841         0       2    0  16.0      0      0   10.5000        S      4
# 844         0       3    0  17.0      0      0    8.6625        S      4
# 850         0       3    0   4.0      4      2   31.2750        S      1
# 869         1       3    0   4.0      1      1   11.1333        S      1
# 877         0       3    0  19.0      0      0    7.8958        S      4
#
# [89 rows x 9 columns]

# %%
df_teen = df_train[(df_train['Age']<60)]

grid = sns.FacetGrid(df_teen, 'Survived')
grid.map(plt.hist,'Sex')

# %%
median_age = np.zeros((2,3))
for dataset in combine:
    for sex in range(0,2):
        for pclass in range(0,3):
            guess_df = dataset[(dataset['Sex'] == sex) & \
                                  (dataset['Pclass'] == pclass+1)]['Age'].dropna()
            age_guess = guess_df.median()
            median_age[sex,pclass] = age_guess
median_age
# Out:
# array([[42., 28., 24.],
#        [41., 24., 22.]])

# %%
for dataset in combine:
    for i in range(0, 2):
        for j in range(0, 3):
            dataset.loc[ (dataset.Age.isnull()) & (dataset.Sex == i) & (dataset.Pclass == j+1),\
                    'Age'] = median_age[i,j]

    dataset['Age'] = dataset['Age'].astype(int)
df_train.head()
# Out:
#    Survived  Pclass  Sex  Age  SibSp  Parch     Fare Embarked  Title
# 0         0       3    0   22      1      0   7.2500        S      4
# 1         1       1    1   38      1      0  71.2833        C      3
# 2         1       3    1   26      0      0   7.9250        S      2
# 3         1       1    1   35      1      0  53.1000        S      3
# 4         0       3    0   35      0      0   8.0500        S      4

# %%
pd.cut(df_train['Age'],5).unique()
# Out:
# [(16.0, 32.0], (32.0, 48.0], (48.0, 64.0], (-0.08, 16.0], (64.0, 80.0]]
# Categories (5, interval[float64]): [(-0.08, 16.0] < (16.0, 32.0] < (32.0, 48.0] < (48.0, 64.0] < (64.0, 80.0]]

# %%
pd.cut(df_train['Sex'],2).unique()
# Out:
# [(-0.001, 0.5], (0.5, 1.0]]
# Categories (2, interval[float64]): [(-0.001, 0.5] < (0.5, 1.0]]

# %%
df_train['AgeBand'] = pd.cut(df_train['Age'], 5)
df_train[['AgeBand', 'Survived']].groupby(['AgeBand'], as_index=False).mean().sort_values(by='AgeBand', ascending=True)
# Out:
#          AgeBand  Survived
# 0  (-0.08, 16.0]  0.550000
# 1   (16.0, 32.0]  0.337374
# 2   (32.0, 48.0]  0.412037
# 3   (48.0, 64.0]  0.434783
# 4   (64.0, 80.0]  0.090909

# %%
for dataset in combine:
    dataset.loc[ dataset['Age'] <= 16, 'AgeG'] = 0
    dataset.loc[(dataset['Age'] > 16) & (dataset['Age'] <= 32), 'AgeG'] = 1
    dataset.loc[(dataset['Age'] > 32) & (dataset['Age'] <= 48), 'AgeG'] = 2
    dataset.loc[(dataset['Age'] > 48) & (dataset['Age'] <= 64), 'AgeG'] = 3
    dataset.loc[ dataset['Age'] > 64, 'AgeG'] = 4

df_train.head()
# Out:
#    Survived  Pclass  Sex  Age  SibSp  Parch     Fare Embarked  Title  \
# 0         0       3    0   22      1      0   7.2500        S      4
# 1         1       1    1   38      1      0  71.2833        C      3
# 2         1       3    1   26      0      0   7.9250        S      2
# 3         1       1    1   35      1      0  53.1000        S      3
# 4         0       3    0   35      0      0   8.0500        S      4
#
#         AgeBand  AgeG
# 0  (16.0, 32.0]   1.0
# 1  (32.0, 48.0]   2.0
# 2  (16.0, 32.0]   1.0
# 3  (32.0, 48.0]   2.0
# 4  (32.0, 48.0]   2.0

# %%
df_train = df_train.drop(['AgeBand','Age'], axis=1)
combine = [df_train, df_test]
df_train.head()
# Out:
#    Survived  Pclass  Sex  SibSp  Parch     Fare Embarked  Title  AgeG
# 0         0       3    0      1      0   7.2500        S      4   1.0
# 1         1       1    1      1      0  71.2833        C      3   2.0
# 2         1       3    1      0      0   7.9250        S      2   1.0
# 3         1       1    1      1      0  53.1000        S      3   2.0
# 4         0       3    0      0      0   8.0500        S      4   2.0

# %%
for dataset in combine:
    dataset['FamilySize'] = dataset['SibSp'] + dataset['Parch'] + 1

df_train[['FamilySize','Survived']].groupby(['FamilySize'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#    FamilySize  Survived
# 3           4  0.724138
# 2           3  0.578431
# 1           2  0.552795
# 6           7  0.333333
# 0           1  0.303538
# 4           5  0.200000
# 5           6  0.136364
# 7           8  0.000000
# 8          11  0.000000

# %%
df_train.head()
# Out:
#    Survived  Pclass  Sex  SibSp  Parch     Fare Embarked  Title  AgeG  \
# 0         0       3    0      1      0   7.2500        S      4   1.0
# 1         1       1    1      1      0  71.2833        C      3   2.0
# 2         1       3    1      0      0   7.9250        S      2   1.0
# 3         1       1    1      1      0  53.1000        S      3   2.0
# 4         0       3    0      0      0   8.0500        S      4   2.0
#
#    FamilySize
# 0           2
# 1           2
# 2           1
# 3           2
# 4           1

# %%
df_train.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# SibSp         0
# Parch         0
# Fare          0
# Embarked      2
# Title         0
# AgeG          0
# FamilySize    0
# dtype: int64

# %%
# Fill embarked empty entries
freq_port = df_train.Embarked.dropna().mode()[0]
freq_port
# Out:
# 'S'

# %%
for dataset in combine:
    dataset['Embarked'] = dataset['Embarked'].fillna(freq_port)

df_train[['Embarked','Survived']].groupby(['Embarked'], as_index = False).mean().sort_values(by='Survived', ascending=False)
# Out:
#   Embarked  Survived
# 0        C  0.553571
# 1        Q  0.389610
# 2        S  0.339009

# %%
df_train.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# SibSp         0
# Parch         0
# Fare          0
# Embarked      0
# Title         0
# AgeG          0
# FamilySize    0
# dtype: int64

# %%
for dataset in combine:
    dataset['Embarked'] = dataset['Embarked'].map( {'S': 0, 'C': 1, 'Q': 2} ).astype(int)

df_train.head()
# Out:
#    Survived  Pclass  Sex  SibSp  Parch     Fare  Embarked  Title  AgeG  \
# 0         0       3    0      1      0   7.2500         0      4   1.0
# 1         1       1    1      1      0  71.2833         1      3   2.0
# 2         1       3    1      0      0   7.9250         0      2   1.0
# 3         1       1    1      1      0  53.1000         0      3   2.0
# 4         0       3    0      0      0   8.0500         0      4   2.0
#
#    FamilySize
# 0           2
# 1           2
# 2           1
# 3           2
# 4           1

# %%
df_train = df_train.drop(['Fare'], axis=1)
df_test = df_test.drop(['Fare'], axis=1)
combine = [df_train, df_test]

df_train.head()
# Out:
#    Survived  Pclass  Sex  SibSp  Parch  Embarked  Title  AgeG  FamilySize
# 0         0       3    0      1      0         0      4   1.0           2
# 1         1       1    1      1      0         1      3   2.0           2
# 2         1       3    1      0      0         0      2   1.0           1
# 3         1       1    1      1      0         0      3   2.0           2
# 4         0       3    0      0      0         0      4   2.0           1

# %%
for dataset in combine:
    dataset.AgeG = dataset.AgeG.astype(int)
df_train.head()
# Out:
#    Survived  Pclass  Sex  SibSp  Parch  Embarked  Title  AgeG  FamilySize
# 0         0       3    0      1      0         0      4     1           2
# 1         1       1    1      1      0         1      3     2           2
# 2         1       3    1      0      0         0      2     1           1
# 3         1       1    1      1      0         0      3     2           2
# 4         0       3    0      0      0         0      4     2           1

# %%
df_test = df_test.drop(['Age'], axis=1)
df_test.head()
# Out:
#    PassengerId  Pclass  Sex  SibSp  Parch  Embarked  Title  AgeG  FamilySize
# 0          892       3    0      0      0         2      4     2           1
# 1          893       3    1      1      0         0      3     2           2
# 2          894       2    0      0      0         2      4     3           1
# 3          895       3    0      0      0         0      4     1           1
# 4          896       3    1      1      1         0      3     1           3
